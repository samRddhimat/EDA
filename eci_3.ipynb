# https://results.eci.gov.in/Result2021/ConstituencywiseS22223.htm?ac=223
# https://results.eci.gov.in/Result2021/ConstituencywiseS22225.htm?ac=225
# https://results.eci.gov.in/Result2021/ConstituencywiseS228.htm?ac=8
# https://results.eci.gov.in/Result2021/ConstituencywiseS2248.htm?ac=48
# https://results.eci.gov.in/Result2021/ConstituencywiseS2244.htm?ac=44
# https://results.eci.gov.in/Result2021/ConstituencywiseS22198.htm?ac=198
# https://results.eci.gov.in/Result2021/ConstituencywiseS2221.htm?ac=21
# https://results.eci.gov.in/Result2021/ConstituencywiseS22105.htm?ac=105
# https://results.eci.gov.in/Result2021/ConstituencywiseS2238.htm?ac=38
# https://results.eci.gov.in/Result2021/ConstituencywiseS2267.htm?ac=67
# https://results.eci.gov.in/Result2021/ConstituencywiseS22183.htm?ac=183
# ...

# %%
# pagecontent = rqst.get("https://results.eci.gov.in/Result2021/ConstituencywiseS2228.htm?ac=28")

# print(len(constituencies))
# data = []
iter=0
column_names=[]
merged_trimmed_data = []
for pagetext in constituencies:
    soup = BeautifulSoup(pagetext)

    #     print('length of table =>',tables)
    table9trs = soup.find_all('table')[9].find('tbody')
    # print(soup.find_all('table')[9]('tr'))
    # print(len(soup.find_all('table')[9]('tr')[1]('td')))
    #     print(soup.find_all('table')[9]('tr')[3]('td')[2])
    #     print(soup.find_all('table')[9]('tr')[3])

    #     print(soup.find_all('table')[9]('tr'))

    if(iter == 0):
        column_names = [ele.text.strip() for ele in table9trs.find_all("th")]
        column_names.insert(0,"Constituency")
    iter = iter + 1
#     print(column_names)
    rows = table9trs.find_all('tr')
#     print(rows)
    data = []
    for row in rows:
        cols = row.find_all('td')
        cols = [ele.text.strip() for ele in cols]
        data.append([ele for ele in cols if ele])    

    trimmed_data = [x for x in data if x]
#     print(trimmed_data)
    
    Constituency_Name = trimmed_data[0]
#     print('Constituency_Name ', Constituency_Name)
    i=0
    for x in trimmed_data:#[2:]:
        trimmed_data[i] = Constituency_Name + trimmed_data[i]
        i=i+1
    merged_trimmed_data = merged_trimmed_data + trimmed_data[2:len(trimmed_data)-1]
#     print(merged_trimmed_data, "\n"*2)
#     print(trimmed_data[2:len(trimmed_data)-1], "\n" *2)
    trimmed_data *= 0
    

# print(len(merged_trimmed_data))

# %%
import pandas as pd

# print(column_names)
# print(len(trimmed_data))
df = pd.DataFrame.from_records(merged_trimmed_data,columns=column_names) #[2:len(merged_trimmed_data)-1]
# for constituency in constituencies:
#     soup = BeautifulSoup(constituency)

# df.query('Consituency.str.contains("Alandur")', engine='python')
# df.query('Party.str.contains("Independent")', engine='python')
# df['Party'] == "Independent"].count().groupby("Constituency")
# df.groupby("Party").sum()

# df["Constituency"].unique()
df
# Out:
#        Constituency O.S.N.                  Candidate  \
# 0           Alandur      1              T.M.Anbarasan
# 1           Alandur      2               B.Valarmathi
# 2           Alandur      3                     N.Raja
# 3           Alandur      4             G Kamalakannan
# 4           Alandur      5           Dr.R.Karthikeyan
# 5           Alandur      6                 Sarathbabu
# 6           Alandur      7                  Subashree
# 7           Alandur      8                Dr.R.Suresh
# 8           Alandur      9  M Mohammed Thameem Ansari
# 9           Alandur     10         Rajesh Chinnadurai
# 10          Alandur     11                  J.Vincent
# 11          Alandur     12                 E.Anbarasu
# 12          Alandur     13                 S.Anbarasu
# 13          Alandur     14                 M Anbarasu
# 14          Alandur     15              M.Ashok Kumar
# 15          Alandur     16                Ali Mohamed
# ...
